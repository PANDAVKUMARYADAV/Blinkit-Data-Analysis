# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'blinkit data.xlsx',
#  'blinkit.ipynb',
#  'Book1.xlsx',
#  'Book2.xlsx',
#  'Clean_Blinkit_Data.xlsx',
#  'DIWALI_SALES.xlsx',
#  'Presonal expenses.xlsx',
#  'Untitled.ipynb']

# %%
import pandas as pd

# %%
df = pd.read_excel('blinkit data.xlsx')

# %%
df.head()
# Out:
#   Item Fat Content Item Identifier Item Type  Outlet Establishment Year  \
# 0         Low Fast         ABC1023      Rice                       2015
# 1         Low Fast         XYZ4587     Bread                       2018
# 2         Low Fast         MNP6734      Milk                       2021
# 3         Low Fast         QWE8912       Egg                       2016
# 4         Low Fast         RTY3456     Apple                       2023
#
#   Outlet Identifier Outlet Location Type Outlet Size   Outlet Type  \
# 0           OUT7431                Tire1       Small  Supermarket3
# 1           OUT1668                Tire1      Medium  Supermarket1
# 2           OUT1116                Tire2        High  Supermarket3
# 3           OUT8434                Tire1        High  Supermarket3
# 4           OUT7215                Tire1       Small  Supermarket3
#
#    Item Visibility  Item Weight  Sales  Rating
# 0        83.829788          4.3  71.72       3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item Fat Content           110 non-null    object
#  1   Item Identifier            110 non-null    object
#  2   Item Type                  110 non-null    object
#  3   Outlet Establishment Year  110 non-null    int64
#  4   Outlet Identifier          110 non-null    object
#  5   Outlet Location Type       110 non-null    object
#  6   Outlet Size                110 non-null    object
#  7   Outlet Type                110 non-null    object
#  8   Item Visibility            110 non-null    float64
#  9   Item Weight                110 non-null    float64
#  10  Sales                      110 non-null    float64
#  11  Rating                     110 non-null    int64
# dtypes: float64(3), int64(2), object(7)
# memory usage: 10.4+ KB

# %%
df.tail()
# Out:
#     Item Fat Content Item Identifier Item Type  Outlet Establishment Year  \
# 105          Regular         QRS1729    Banana                       2019
# 106          Regular         TUV6854    Orange                       2025
# 107          Regular         WXY3908     Mango                       2017
# 108          Regular         ZAB7142    Grapes                       2020
# 109          Regular         CDE2587    Potato                       2022
#
#     Outlet Identifier Outlet Location Type Outlet Size   Outlet Type  \
# 105           OUT2042                Tire1       Small  Supermarket2
# 106           OUT3336                Tire3       Small  Supermarket3
# 107           OUT5577                Tire2       Small  Supermarket2
# 108           OUT2513                Tire1        High  Supermarket1
# 109           OUT5031                Tire1      Medium  Supermarket2
#
#      Item Visibility  Item Weight  Sales  Rating
# 105        25.647501          1.8  49.19       5
# ...

# %%
df.shape
# Out:
# (110, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item Fat Content           110 non-null    object
#  1   Item Identifier            110 non-null    object
#  2   Item Type                  110 non-null    object
#  3   Outlet Establishment Year  110 non-null    int64
#  4   Outlet Identifier          110 non-null    object
#  5   Outlet Location Type       110 non-null    object
#  6   Outlet Size                110 non-null    object
#  7   Outlet Type                110 non-null    object
#  8   Item Visibility            110 non-null    float64
#  9   Item Weight                110 non-null    float64
#  10  Sales                      110 non-null    float64
#  11  Rating                     110 non-null    int64
# dtypes: float64(3), int64(2), object(7)
# memory usage: 10.4+ KB

# %%
df.columns
# Out:
# Index(['Item Fat Content', 'Item Identifier', 'Item Type',
#        'Outlet Establishment Year', 'Outlet Identifier',
#        'Outlet Location Type', 'Outlet Size', 'Outlet Type', 'Item Visibility',
#        'Item Weight', 'Sales', 'Rating'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Outlet Establishment Year  Item Visibility  Item Weight       Sales  \
# count                 110.000000       110.000000   110.000000  110.000000
# mean                 2020.054545        57.263875     3.043636   56.779455
# std                     3.082464        25.699107     1.236489   24.164433
# min                  2015.000000        11.225538     1.100000   11.740000
# 25%                  2018.000000        37.459916     2.025000   40.085000
# 50%                  2020.000000        54.215109     3.000000   61.410000
# 75%                  2023.000000        82.438900     4.100000   75.055000
# max                  2025.000000        99.511662     5.000000   99.970000
#
#            Rating
# count  110.000000
# mean     3.990909
# std      0.840440
# min      3.000000
# 25%      3.000000
# 50%      4.000000
# 75%      5.000000
# max      5.000000

# %%
df.drop_duplicates(inplace=True)

# %%
df['Item Type'].unique()
# Out:
# array(['Rice', 'Bread', 'Milk', 'Egg', 'Apple', 'Banana', 'Orange',
#        'Mango', 'Grapes', 'Potato', 'Tomato', 'Onion', 'Carrot',
#        'Cabbage', 'Spinach', 'Peas', 'Lentils', 'Beans', 'Chicken',
#        'Fish', 'Meat', 'Butter', 'Cheese', 'Yogurt', 'Sugar', 'Salt',
#        'Tea', 'Coffee', 'Juice', 'Soup', 'Cake', 'Biscuit', 'Chocolate',
#        'Ice Cream', 'Noodles', 'Pasta', 'Pizza', 'Burger', 'Sandwich',
#        'Salad', 'Pickle', 'Honey', 'Jam', 'Corn', 'Nuts', 'Coconut',
#        'Watermelon', 'Papaya', 'Sweets', 'Porridge'], dtype=object)

# %%
df['Sales'].sum()
# Out:
# np.float64(6245.739999999999)

# %%
df['Sales'].mean()
# Out:
# np.float64(56.779454545454534)

# %%
df['Sales'].max()
# Out:
# 99.97

# %%
df['Sales'].min()
# Out:
# 11.74

# %%
df.to_excel('Clean_Blinkit_Data.xlsx', index=False)
